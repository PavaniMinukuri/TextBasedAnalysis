# %%
# Loading libraries
import pandas as pd

# %% [markdown]
# # Question-1

# %%
# Reading the data
df=pd.read_csv(r"C:\Users\pavan\Downloads\data_science_jobs_indeed_usa.csv\data_science_jobs_indeed_usa.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0                                     Data Scientist
# 1           1                                   Business Analyst
# 2           2  IT Business Intelligence Developer (FT) Remote...
# 3           3                                      Data Engineer
# 4           4                Network Administrator/dba developer
#
#                    Company                              Location  Rating  \
# 0            Driven Brands                           Benicia, CA     2.4
# 1         Sabot Consulting                                Remote     NaN
# 2            Ballad Health             Remote in Blountville, TN     3.0
# 3  Longevity Holdings Inc.  Remote in Minneapolis-Saint Paul, MN     NaN
# 4             WKI Kenworth                     Wichita, KS 67219     NaN
#
#                         Date                     Salary  \
# 0   PostedPosted 26 days ago                        NaN
# ...

# %%
# importing nltk library from that stopwords
import nltk 
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'its', 'ourselves', 'until', "aren't", 'have', 'over', 'having', 'now', 'not', 'am', 'itself', 'why', "you've", 'by', "you're", 'at', 've', 'to', 'been', 'into', 'has', 'own', 'under', "couldn't", 'mustn', 'before', "weren't", 'that', "that'll", 'these', 'few', 'as', "mightn't", 'but', "you'll", 'haven', 'him', 'from', 'with', 'most', 'couldn', 's', 'shouldn', 'for', 'wasn', 'yourself', "she's", 'our', 'your', 'mightn', 'were', 'all', 'who', 'below', 'out', "needn't", 'i', 're', 'and', 'above', 'such', 'they', 'which', 'because', 't', 'then', "should've", "wouldn't", 'about', 'any', 'off', 'than', 'very', 'it', 'some', 'yourselves', 'them', 'nor', 'won', 'being', 'me', 'between', 'ours', 'too', 'there', 'doesn', 'be', 'her', 'don', 'myself', 'themselves', "hasn't", 'both', 'other', 'how', 'down', 'yours', 'had', "shouldn't", 'is', 'ain', 'more', 'd', 'theirs', 'you', 'if', "wasn't", 'my', 'doing', 'an', 'just', 'against', 'can', 'once', 'through', 'are', 'isn', "doesn't", "don't", '
# ...

# %%
import regex as re

# using regex removing stop words

def remove_stop(text):
    '''   cleaning the text     '''
    # Replace special characters with spaces
    text = re.sub(r"[,.\"\'!@#$%^&*(){}?/;`~:<>+=-\\\n]", " ", text)
    tokens = text.split()  # Split the text into tokens
    filtered_tokens = [token.lower() for token in tokens if token.lower() not in stopwords]
    # Join the filtered tokens back into a string
    return filtered_tokens

pipeline = [remove_stop]

def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

df['tokens'] = df['Descriptions'].apply(prepare, pipeline=pipeline)

# %%
df['tokens']
# Out:
# 0       [e, invite, join, us, riven, rands, eadquarter...
# 1       [abot, onsulting, abot, management, consulting...
# 2         [ob, etails, pply, ave, rint, job, mail, riend]
# 3       [osition, ata, ngineer, ocation, ata, ngineer,...
# 4       [ull, ob, escription, etwork, dministrator, pr...
#                               ...
# 1195    [ompany, escription, yperscience, transforming...
# 1196    [ob, itle, -, ata, cientist, osition, -, 2, mp...
# 1197    [ata, ngineer, ower, ocation, emote, ased, ara...
# 1198    [n, role, opportunity, major, impact, value, c...
# 1199    [osition, usiness, nalyst, ocation, emote, ura...
# Name: tokens, Length: 1200, dtype: object

# %% [markdown]
# QUESTION-2

# %%
# Statistical description of data
df.describe(include='O')
# Out:
#                 Title                Company Location  \
# count            1200                   1200     1200
# unique            566                    883      584
# top     Data Engineer  Artech Consulting LLC   Remote
# freq               93                     10      283
#
#                              Date             Salary  \
# count                        1200                582
# unique                         46                381
# top     PostedPosted 30+ days ago  $60 - $65 an hour
# freq                          390                 12
#
#                                               Description  \
# count                                                1200
# unique                                               1016
# top     Experience with data science, data engineering...
# freq                                                    9
#
#                                                     Links  \
# count                                                1200
# ...

# %% [markdown]
# VISUALIZATION

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# HISSTOGRAM

# %%
# Create a histogram
sns.histplot(df['Title'].head(50), kde=True)
plt.title('Histogram')
plt.xlabel('Title')
plt.ylabel('Frequency')
plt.xticks(rotation=90)  # Rotate x-axis labels by 45 degrees
plt.show()
# Out:
# C:\Users\pavan\Downloads\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Question-3

# %%
# Counting the frequency of the tokens and Assuming df is already defined
from collections import Counter
counter = Counter()
df['tokens'].map(counter.update)
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#             freq
# token
# data        7505
# experience  3878
# business    3333
# xperience   2898
# e           2855
# team        2835
# work        2632
# ata         2439
# years       2108
# skills      1775

# %%
## displays a word cloud visualization from a DataFrame of word frequencies using the WordCloud library and Matplotlib.
from wordcloud import WordCloud


# Create the WordCloud object with better clarity settings
wc = WordCloud(
    background_color='white', 
    width=800, 
    height=800, 
    margin=2, 
    max_words=200, 
    max_font_size=100, 
    collocations=False
)

# Fit the WordCloud object with word frequencies
wc.fit_words(freq_df['freq'].to_dict())

# Plot the word cloud
plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# Cleaning the text by performing tokenization, removing the stopwords and preprocessing the text.
import regex as re

def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
pipeline = [str.lower, tokenize, remove_stop]

def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens
df['token1'] = df['Descriptions'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# QUESTION -4

# %% [raw]
# 1. Email regex: (`r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'`):
#    - This regex pattern is used to match email addresses.
#    - `\b`: Matches a word boundary, ensuring that the email address is a standalone word.
#    - `[A-Za-z0-9._%+-]+`: Matches one or more characters that are either letters, digits, or any of the specified special characters (`._%+-`).
#    - `@`: Matches the "@" symbol.
#    - `[A-Za-z0-9.-]+`: Matches one or more characters that are either letters, digits, or the "." or "-" symbols.
#    - `\.`: Matches the "." symbol.
#    - `[A-Z|a-z]{2,}`: Matches two or more letters (upper or lower case) representing the top-level domain (TLD).
#    - `\b`: Matches another word boundary, ensuring the end of the email address.
#
# 2. Phone number regex:(`r'\(?\d{3}\)?[\s.-]?\d{3}[\s.-]?\d{4}'`):
#    - This regex pattern is used to match phone numbers in various formats.
#    - `\(?`: Matches an optional opening parenthesis "(".
#    - `\d{3}`: Matches exactly three digits.
#    - `\)?`: Matches an optional closing parenthesis ")".
#    - `[\s.-]?`: Matches an optional whitespace, dot, or hyphen.
#    - `\d{3}`: Matches exactly three digits.
#    - `[\s.-]?`: Matches an optional whitespace, dot, or hyphen.
#    - `\d{4}`: Matches exactly four digits.
#
# 3. File path regex: (`r'\/(?:[^\/\n]+\/)*([^\/\n]+\.[^\/\n]+)'`):
#    - This regex pattern is used to match file paths.
#    - `\/`: Matches the "/" symbol.
#    - `(?:[^\/\n]+\/)*`: Non-capturing group that matches zero or more occurrences of one or more characters that are not "/", followed by a "/".
#    - `([^\/\n]+\.[^\/\n]+)`: Capturing group that matches one or more characters that are not "/" or newline, followed by a ".", followed by one or more characters that are not "/" or newline.
#
# 4. URL regex: (`r'^(https?:\/\/)?(?:www\.)?([^\/\n]+)(\/.*)?$'`):
#    - This regex pattern is used to match URLs.
#    - `^`: Matches the start of the string.
#    - `(https?:\/\/)?`: Optional capturing group that matches "http://" or "https://".
#    - `(?:www\.)?`: Non-capturing group that matches an optional "www.".
#    - `([^\/\n]+)`: Capturing group that matches one or more characters that are not "/" or newline (the domain).
#    - `(\/.*)?`: Optional capturing group that matches a "/" followed by zero or more characters (the path).
#    - `$`: Matches the end of the string.
#
# 5. Hashtag regex: (`r'#\w+'`):
#    - This regex pattern is used to match hashtags.
#    - `#`: Matches the "#" symbol.
#    - `\w+`: Matches one or more word characters (letters, digits, or underscores), representing the hashtag.

# %%
a=['minukuripavani08@gmail.com', '(123) 456-7890','/home/user/data/file.txt','https://www.example.com/page.html','#DataScience #MachineLearning #AI']

# Email regex
regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
result = re.match(regex,a[0])
print(result.group())

# Phone number regex
regex = r'\(?\d{3}\)?[\s.-]?\d{3}[\s.-]?\d{4}'
result = re.match(regex, a[1])
print(result.group())



# text file regex
regex = r'\/(?:[^\/\n]+\/)*([^\/\n]+\.[^\/\n]+)'
result = re.match(regex, a[2])
print(result.group(1))


# URL regex
regex = r'^(https?:\/\/)?(?:www\.)?([^\/\n]+)(\/.*)?$'
result = re.match(regex, a[3])
print("Protocol:", result.group(1))
print("Domain:", result.group(2))
print("Path:", result.group(3))


# web page html domain regex
regex = r'#\w+'
result = re.findall(regex, a[4])
print(result)
# Out:
# minukuripavani08@gmail.com
# (123) 456-7890
# file.txt
# Protocol: https://
# Domain: example.com
# Path: /page.html
# ['#DataScience', '#MachineLearning', '#AI']

# %% [markdown]
# # sentiment analysis QUESTION 5

# %%
from textblob import TextBlob

# %%
# Create a function to get the subjectivity
def getSubjectivity(tokens):
    text = ' '.join(tokens)  # Convert list of tokens to a single string
    return TextBlob(text).sentiment.subjectivity

# Create a function to get polarity
def getPolarity(tokens):
    text = ' '.join(tokens)  # Convert list of tokens to a single string
    return TextBlob(text).sentiment.polarity

# Now we create new columns for subjectivity and polarity and add them to the DataFrame
df['Subjectivity'] = df['token1'].apply(getSubjectivity)
df['Polarity'] = df['token1'].apply(getPolarity)

# Display the DataFrame
df.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0                                     Data Scientist
# 1           1                                   Business Analyst
# 2           2  IT Business Intelligence Developer (FT) Remote...
# 3           3                                      Data Engineer
# 4           4                Network Administrator/dba developer
#
#                    Company                              Location  Rating  \
# 0            Driven Brands                           Benicia, CA     2.4
# 1         Sabot Consulting                                Remote     NaN
# 2            Ballad Health             Remote in Blountville, TN     3.0
# 3  Longevity Holdings Inc.  Remote in Minneapolis-Saint Paul, MN     NaN
# 4             WKI Kenworth                     Wichita, KS 67219     NaN
#
#                         Date                     Salary  \
# 0   PostedPosted 26 days ago                        NaN
# ...
